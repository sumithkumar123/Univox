# %% [markdown]
# # RVC v2 Disconnected
#
# **Notebook hastily written by [Kit Lemonfoot](https://huggingface.co/Kit-Lemonfoot) / [Noel Shirogane's High Flying Birds](https://www.youtube.com/@NoelShiroganesHighFlyingBirds)**
#
# *Based on the work of the [RVC Project](https://github.com/RVC-Project), [Mangio261](https://github.com/Mangio621/), [Kalomaze](https://github.com/kalomaze), [Alexlnkp](https://github.com/alexlnkp), the [Pony Preservation Project](https://boards.4channel.org/mlp/catalog#s=Pony%20Preservation%20Project), and many others in the RVC / voice AI community* ❤
#
# *Notebook version:* **0.28**
#
# ---
#
#
# This notebook is designed to be used with training Retreival-Based Voice Conversion models without using a WеbUl. This is done to stay within the scope of Colab's TOS (and also because I personally don't like WеbUls.)
#
# This notebook is *not* designed to be used for inference. Colab should not be used for RVC inference in general, use local inference instead. (RVC can inference just fine on any dime-a-dozen CPU from the past 7 years, you seriously don't need Colab.)
#
# ⚠ WARNING: Unlike the original RVC notebook, *this notebook ***does not*** have autosave functionality* due to the massive amount of underlying stress that RVC's autosave features places on Colab to Drive communication. Please be careful and try to keep training sessions short.

# %%
# You will likely want a disconnect prevention method to keep Colab from timing you out for "inactivity" during training.
# I won't be providing one here, but they're not hard to come by. Search around the Colab AI community and you'll find one. ;)

# %% [markdown]
# # Dependencies
# Run me first!

# %%
#@title Install Dependencies
#Credit to Nick088 for fixing this cell on short order from the Fairseq bugginess.
import subprocess

packages = ['build-essential', 'python3-dev', 'ffmpeg', 'aria2']
pip_packages = ['setuptools', 'wheel', 'faiss-gpu', 'fairseq', 'ffmpeg', 'ffmpeg-python', 'praat-parselmouth', 'pyworld', 'numpy==1.23.5', 'numba==0.56.4', 'librosa==0.9.2']

print("Updating and installing system packages...")
for package in packages:
  print(f"Installing {package}...")
  subprocess.check_call(['apt-get', 'install', '-qq', '-y', package])

print("Updating and installing pip packages...")
# Install pip packages individually to identify problematic ones

# downgrade pip
# !pip install --upgrade pip==23.1
# install packages
for package in pip_packages:
  print(f"Installing {package}...")
  subprocess.check_call(['pip', 'install', '--upgrade', package])

print('Packages up to date.')
firsttry = True
# Out:
# Updating and installing system packages...
# Installing build-essential...
# Installing python3-dev...
# Installing ffmpeg...
# Installing aria2...
# Updating and installing pip packages...
# Requirement already satisfied: pip==23.1 in /usr/local/lib/python3.10/dist-packages (23.1)
# Installing setuptools...
# Installing wheel...
# Installing faiss-gpu...
# Installing fairseq...
# Installing ffmpeg...
# Installing ffmpeg-python...
# Installing praat-parselmouth...
# Installing pyworld...
# Installing numpy==1.23.5...
# Installing numba==0.56.4...
# Installing librosa==0.9.2...
# Packages up to date.

# %%
#@title Clone Repositories
import os

# READ ME BEFORE CHANGING THINGS
# If you're attempting to replace the imports here with Applio-RVC, it will not work due to requirement discrepancies across the entire notebook.
# I will not be porting this notebook to Applio due to the failure of the Applio team to provide backwards compatibility with the Crepe and Mangio-Crepe f0 feature format.
# DO NOT ASK. IT WILL NOT HAPPEN.

os.chdir('/content/')

if(os.path.exists("/content/Mangio-RVC-Fork")):
  print("RVC already installed, skipping.")
else:
  #Credit to miaaaa0a on the AI Hub Discord for (indirectly) suggesting this variant of Mangio RVC to me.
  # !git clone -b pr-optimization --single-branch https://github.com/alexlnkp/Mangio-RVC-Tweaks.git
  #Rename to keep backwards compatibility with old variants of Disconnected
  os.rename("/content/Mangio-RVC-Tweaks", "/content/Mangio-RVC-Fork")
  # !git clone https://github.com/maxrmorrison/torchcrepe.git
  # !mv torchcrepe/torchcrepe Mangio-RVC-Fork/
  # !rm -rf torchcrepe  # Delete the torchcrepe repository folder

os.chdir('/content/Mangio-RVC-Fork')
now_dir = "/content/Mangio-RVC-Fork"
os.makedirs(os.path.join(now_dir, "logs"), exist_ok=True)
os.makedirs(os.path.join(now_dir, "weights"), exist_ok=True)
# Out:
# RVC already installed, skipping.

# %%
#@title GPU Check
import torch

ngpu = torch.cuda.device_count()
gpu_infos = []
mem = []
if_gpu_ok = False

if torch.cuda.is_available() or ngpu != 0:
  for i in range(ngpu):
    gpu_name = torch.cuda.get_device_name(i)
    if any(
        value in gpu_name.upper()
        for value in ["10", "16", "20", "30", "40", "A2", "A3", "A4", "P4", "A50", "500", "A60", "70", "80", "90", "M4", "T4", "TITAN"]
    ):
      if_gpu_ok = True
      print("Compatible GPU detected: %s" % gpu_name)
      gpu_infos.append("%s\t%s" % (i, gpu_name))
      mem.append(int(torch.cuda.get_device_properties(i).total_memory / 1024 / 1024 / 1024 + 0.4))

if if_gpu_ok and len(gpu_infos) > 0:
  gpu_info = "\n".join(gpu_infos)

else:
  raise Exception("No GPU detected; training cannot continue. Please change your runtime type to a GPU.")
gpus = "-".join(i[0] for i in gpu_infos)
# Out:
# Compatible GPU detected: Tesla T4

# %%
#@title Mount Drive
from google.colab import drive
if not os.path.exists('/content/drive'):
  drive.mount('/content/drive')
else:
  print('Drive is already mounted. Proceed.')

os.makedirs('/content/drive/MyDrive/rvcDisconnected', exist_ok=True)
# Out:
# Drive is already mounted. Proceed.

# %%
#@title Download Extra Files
#Didn't ask.

#Hubert/RMVPE
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Kit-Lemonfoot/RVC_DidntAsk/resolve/main/hubert_base.pt -d /content/Mangio-RVC-Fork -o hubert_base.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Kit-Lemonfoot/RVC_DidntAsk/resolve/main/rmvpe.pt -d /content/Mangio-RVC-Fork -o rmvpe.pt

#FM JSONs
# !rm -rf /content/Mangio-RVC-Fork/configs/32k.json
# !rm -rf /content/Mangio-RVC-Fork/configs/40k.json
# !rm -rf /content/Mangio-RVC-Fork/configs/48k.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Kit-Lemonfoot/RVC_DidntAsk/resolve/main/32k.json -d /content/Mangio-RVC-Fork/configs -o 32k.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Kit-Lemonfoot/RVC_DidntAsk/resolve/main/40k.json -d /content/Mangio-RVC-Fork/configs -o 40k.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/Kit-Lemonfoot/RVC_DidntAsk/resolve/main/48k.json -d /content/Mangio-RVC-Fork/configs -o 48k.json
# Out:
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 542c15|OK  |       0B/s|/content/Mangio-RVC-Fork/hubert_base.pt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# f3e6c8|OK  |       0B/s|/content/Mangio-RVC-Fork/rmvpe.pt
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# cd4eda|OK  |   127KiB/s|/content/Mangio-RVC-Fork/configs/32k.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 43a33c|OK  |   145KiB/s|/content/Mangio-RVC-Fork/configs/40k.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 083a1f|OK  |   170KiB/s|/content/Mangio-RVC-Fork/configs/48k.json
#
# Status Legend:
# (OK):download completed.

# %%
#@title Setup CSVDB
#...Alright, you made your point.
import csv

if not os.path.isdir("csvdb/"):
  os.makedirs("csvdb")
  frmnt, stp = open("csvdb/formanting.csv", "w", newline=""), open("csvdb/stop.csv", "w", newline="")
  csv_writer = csv.writer(frmnt, delimiter=",")
  csv_writer.writerow([False, 1.0, 1.0])
  csv_writer = csv.writer(stp, delimiter=",")
  csv_writer.writerow([False])
  frmnt.close()
  stp.close()

global DoFormant, Quefrency, Timbre
DoFormant, Quefrency, Timbre = False, 1.0, 1.0

# %% [markdown]
# # Initial Setup
# You need to run these cells for every training session.

# %%
#@title Set Training Variables
now_dir = "/content/Mangio-RVC-Fork"
experiment_name = "Nethaji1" #@param {type:"string"}
path_to_training_folder = "/content/dataset/"
model_architecture = "v2" #@param ["v1","v2"] {allow-input: false}
target_sample_rate = "40k" #@param ["32k", "40k", "48k"] {allow-input: false}
speaker_id = 0 #@param {type:"integer"}
pitch_extraction_algorithm = "rmvpe" #@param ["harvest", "crepe", "mangio-crepe", "rmvpe"] {allow-input: false}
crepe_hop_length = 64 #@param {type:"integer"}
pitch_guidance = True #@param {type:"boolean"}

cpu_threads = !nproc
cpu_threads = int(cpu_threads[0])

exp_dir = f"{now_dir}/logs/{experiment_name}"

assert crepe_hop_length!=None, "You need to input something for crepe_hop_length, silly."
assert crepe_hop_length>0, "Hop length must be more than 0."
assert crepe_hop_length<=512, "Save frequency must be less than 512."

if(experiment_name == "experiment_name"):
  print("Warning: Your experiment name should be changed to the name of your dataset.")

# %%
#@title Download Pretrained Model
#@markdown What pretrained model would you like to use?
pretrain_type = "OV2Super" #@param ["original", "OV2Super", "RIN_E3", "ItaIla", "SnowieV3", "SnowieV3xRIN_E3", "TITAN", "custom"] {allow-input: false}
#@markdown **Advanced:** Set your pretrain type to "custom" and input HuggingFace links to your G and D files here.
g="" #@param {type:"string"}
d="" #@param {type:"string"}
assert 'model_architecture' in locals(), "Hold up! You need to run Set Training Variables first."

if pretrain_type!="original" and model_architecture!="v2":
  model_architecture="v2"
  print("The new pretrains only support RVC v2 at this time. Your settings have been automatically adjusted.")

if pretrain_type=="OV2Super" and target_sample_rate=="48k":
  target_sample_rate="40k"
  print("OV2Super only supports 40k and lower at this time. Your settings have been automatically adjusted.")
if pretrain_type=="RIN_E3" and target_sample_rate!="40k":
  target_sample_rate="40k"
  print("RIN_E3 only supports 40k at this time. Your settings have been automatically adjusted.")
if pretrain_type=="ItaIla" and target_sample_rate!="32k":
  target_sample_rate="32k"
  print("ItaIla only supports 32k at this time. Your settings have been automatically adjusted.")
if pretrain_type=="SnowieV3xRIN_E3" and target_sample_rate!="40k":
  target_sample_rate="40k"
  print("SnowieV3 x RIN_E3 only supports 40k at this time. Your settings have been automatically adjusted.")

#Setup link
print("Setting up...")
if pretrain_type=="original" and model_architecture=="v2":
  g = f"https://huggingface.co/Kit-Lemonfoot/RVC_DidntAsk/resolve/main/f0G{target_sample_rate}.pth"
  d = f"https://huggingface.co/Kit-Lemonfoot/RVC_DidntAsk/resolve/main/f0D{target_sample_rate}.pth"
if pretrain_type=="original" and model_architecture=="v1":
  g = f"https://huggingface.co/Kit-Lemonfoot/RVC_DidntAsk/resolve/main/v1/f0G{target_sample_rate}.pth"
  d = f"https://huggingface.co/Kit-Lemonfoot/RVC_DidntAsk/resolve/main/v1/f0D{target_sample_rate}.pth"
if pretrain_type=="OV2Super" and target_sample_rate=="40k":
  g = f"https://huggingface.co/ORVC/Ov2Super/resolve/main/f0Ov2Super{target_sample_rate}G.pth"
  d = f"https://huggingface.co/ORVC/Ov2Super/resolve/main/f0Ov2Super{target_sample_rate}D.pth"
if pretrain_type=="OV2Super" and target_sample_rate=="32k":
  g = f"https://huggingface.co/poiqazwsx/Ov2Super32kfix/resolve/main/f0Ov2Super32kD.pth"
  d = f"https://huggingface.co/poiqazwsx/Ov2Super32kfix/resolve/main/f0Ov2Super32kD.pth"
if pretrain_type=="RIN_E3":
  g = "https://huggingface.co/MUSTAR/RIN_E3/resolve/main/RIN_E3_G.pth"
  d = "https://huggingface.co/MUSTAR/RIN_E3/resolve/main/RIN_E3_D.pth"
if pretrain_type=="SnowieV3":
  g = f"https://huggingface.co/MUSTAR/SnowieV3.1-{target_sample_rate}/resolve/main/G_SnowieV3.1_{target_sample_rate}.pth"
  d = f"https://huggingface.co/MUSTAR/SnowieV3.1-{target_sample_rate}/resolve/main/D_SnowieV3.1_{target_sample_rate}.pth"
if pretrain_type=="ItaIla":
  g = "https://huggingface.co/TheStinger/itaila/resolve/main/ItaIla_32k_G.pth"
  d = "https://huggingface.co/TheStinger/itaila/resolve/main/ItaIla_32k_D.pth"
if pretrain_type=="SnowieV3xRIN_E3":
  g = "https://huggingface.co/MUSTAR/SnowieV3.1-X-RinE3-40K/resolve/main/G_Snowie-X-Rin_40k.pth"
  d = "https://huggingface.co/MUSTAR/SnowieV3.1-X-RinE3-40K/resolve/main/D_Snowie-X-Rin_40k.pth"
if pretrain_type=="TITAN":
  g = f"https://huggingface.co/blaise-tk/TITAN/resolve/main/models/medium/{target_sample_rate}/pretrained/G-f0{target_sample_rate}-TITAN-Medium.pth"
  d = f"https://huggingface.co/blaise-tk/TITAN/resolve/main/models/medium/{target_sample_rate}/pretrained/D-f0{target_sample_rate}-TITAN-Medium.pth"

pretrained_base = "pretrained/" if model_architecture == "v1" else "pretrained_v2/"
unpt = f"_{pretrain_type}" if pretrain_type!="original" else ""

print("Downloading your pretrained model...")
# !aria2c --console-log-level=error -q -c -x 16 -s 16 -k 1M {g} -d /content/Mangio-RVC-Fork/{pretrained_base} -o f0G{target_sample_rate}{unpt}.pth
# !aria2c --console-log-level=error -q -c -x 16 -s 16 -k 1M {d} -d /content/Mangio-RVC-Fork/{pretrained_base} -o f0D{target_sample_rate}{unpt}.pth

print("Pretrain downloaded. Best of luck training!")
# Out:
# Setting up...
# Downloading your pretrained model...
# Pretrain downloaded. Best of luck training!

# %% [markdown]
# #Preprocessing
# You should only need to run these cells once per model.

# %%
#@title Load Dataset
#@markdown If it doesn't already exist, create a folder in your Google Drive named 'rvcDisconnected' and place your zip file there. This will look for the following ZIP file inside that 'rvcDisconnected' folder.
dataset = "Nethaji_input_audio.zip"  #@param {type:"string"}

#@markdown This loader will load datasets in a similar fashion to the So-Vits-SVC dataset loader. For best results, your dataset should be formatted as such:
#@markdown ```
#@markdown zipfile.zip
#@markdown └───character_name
#@markdown     ├───file1.wav
#@markdown     ├───...
#@markdown     └───file999.wav
#@markdown ```
#@markdown Audio filenames do not matter. All audio files should be in WAV format for best compatibility.

# TODO: Add something to convert non-WAVs to WAV

import os
import shutil

directories=[]

def sanitize_directory(directory):
  for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)
    if os.path.isfile(file_path):
      if filename == ".DS_Store" or filename.startswith("._") or not filename.endswith(('.wav', '.flac', '.mp3', '.ogg', '.m4a')):
        os.remove(file_path)
    elif os.path.isdir(file_path):
      #Get rid of the MACOSX directory just so it doesn't mess with renaming later
      if(filename == "__MACOSX"):
        shutil.rmtree(file_path)
        continue
      #Append the directory to directories for future dataset check, then recurse.
      directories.append(file_path)
      sanitize_directory(file_path)

dataset_path = '/content/drive/MyDrive/rvcDisconnected/' + dataset
final_directory = '/content/dataset'
temp_directory = '/content/temp_dataset'

if os.path.exists(final_directory):
  print("Dataset folder already found. Wiping...")
  shutil.rmtree(final_directory)
if os.path.exists(temp_directory):
  print("Temporary folder already found. Wiping...")
  shutil.rmtree(temp_directory)

if not os.path.exists(dataset_path):
  raise Exception(f'I can\'t find {dataset} in {os.path.dirname(dataset_path)}.')

os.makedirs(final_directory, exist_ok=True)
os.makedirs(temp_directory, exist_ok=True)
#Oops.
# !unzip -d "{temp_directory}" -B "{dataset_path}"
print("Sanitizing...")
sanitize_directory(temp_directory)

if(len(directories) == 0):
  #If there's no directories, we're dealing with a ZIP of just audio files.
  #Move everything to /dataset/experiment_name/.
  print("Dataset Type: Audio Files (Single Speaker)")
  expDir=os.path.join(final_directory, experiment_name)
  os.makedirs(expDir, exist_ok=True)
  for r, _, f in os.walk(temp_directory):
    for name in f:
      # !cp "{temp_directory}/{name}" "{expDir}"
elif(len(directories) == 1):
  #If there's only one directory, we're dealing with a single speaker.
  #Rename the folder to experiment_name and move it to /dataset/.
  print("Dataset Type: Single Speaker")
  fi = os.path.join(temp_directory, experiment_name)
  os.rename(directories[0], fi)
  shutil.move(fi, final_directory)

else:
  #If anything else, we're dealing with multispeaker.
  #Move all folders to /dataset/ indiscriminately.
  print("Dataset Type: Multispeaker")
  for fi in directories:
    shutil.move(fi, final_directory)

shutil.rmtree(temp_directory)

print("Dataset imported.")
# Out:
# Dataset folder already found. Wiping...
# Archive:  /content/drive/MyDrive/rvcDisconnected/Nethaji_input_audio.zip
#   inflating: /content/temp_dataset/NethajiReddy/Sound01.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound02.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound03.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound04.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound05.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound06.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound07.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound08.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound09.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound10.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound11.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound12.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound13.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound14.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound15.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound16.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound17.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound18.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound19.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound20.wav
#   inflating: /content/temp_dataset/NethajiReddy/Sound21.wav
# Sanitizing...
# Dataset Type: Single Speaker
# Dataset imported.

# %%
#@title Preprocessing and Feature Extraction

import os
import subprocess

assert cpu_threads>0, "CPU threads not allocated correctly."

sr = int(target_sample_rate.rstrip('k'))*1000
pttf = path_to_training_folder + experiment_name
os.makedirs(f"{exp_dir}", exist_ok=True)

cmd = f"python trainset_preprocess_pipeline_print.py \"{pttf}\" {sr} {cpu_threads} \"{exp_dir}\" 1"
print(cmd)
# !$cmd

gpuList = gpus.split("-")
cmd = f"python extract_f0_print.py \"{exp_dir}\" {cpu_threads} {pitch_extraction_algorithm} {crepe_hop_length}"
print(cmd)
# !$cmd

leng = len(gpus)
cmd = f"python extract_feature_print.py \"device\" {leng} 0 0 \"{exp_dir}\" {model_architecture}"
print(cmd)
# !$cmd
# Out:
# python trainset_preprocess_pipeline_print.py "/content/dataset/Nethaji1" 40000 2 "/content/Mangio-RVC-Fork/logs/Nethaji1" 1
# start preprocess
# ['trainset_preprocess_pipeline_print.py', '/content/dataset/Nethaji1', '40000', '2', '/content/Mangio-RVC-Fork/logs/Nethaji1', '1']
# thread:0:   0% 0/11 [00:00<?, ?it/s]
# thread:1:   0% 0/10 [00:00<?, ?it/s]
# thread:0:   9% 1/11 [00:05<00:59,  5.92s/it]
# thread:0:  18% 2/11 [00:10<00:46,  5.11s/it]
# thread:0:  27% 3/11 [00:13<00:32,  4.00s/it]
# thread:0:  36% 4/11 [00:15<00:24,  3.44s/it]
# thread:0:  45% 5/11 [00:18<00:18,  3.16s/it]
# thread:0:  55% 6/11 [00:21<00:15,  3.15s/it]
# thread:0:  64% 7/11 [00:25<00:14,  3.54s/it]
# thread:0:  73% 8/11 [00:29<00:10,  3.48s/it]
# thread:0:  82% 9/11 [00:31<00:06,  3.21s/it]
# thread:1: 100% 10/10 [00:33<00:00,  3.38s/it]
# thread:0: 100% 11/11 [00:35<00:00,  3.22s/it]
# end preprocess
# python extract_f0_print.py "/content/Mangio-RVC-Fork/logs/Nethaji1" 2 rmvpe 64
# ['extract_f0_print.py', '/content/Mangio-RVC-Fork/logs/Nethaji1', '2', 'rmvpe', '64']
# Using f0 method: rmvpe
# thread:0, f0ing, Hop-Length:64: 100% 195/195 [00:00<00:00, 71575.15it/s]
#
#   0% 0/194 [00:00<?, ?it/s]
# thread:1, f0ing, Hop-Length:64: 100% 194/194 [00:00<00:00, 76583.06it/s]
# python extract_feature_print.py "device" 1 0 0 "/content/Mangio-RVC-Fork/logs/Nethaji1" v2
# 2024-11-17 15:27:37.432086: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-17 15:27:37.472417: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-17 15:27:37.485254: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-17 15:27:37.515728: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-11-17 15:27:39.071624: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-11-17 15:27:42 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# ['extract_feature_print.py', 'device', '1', '0', '0', '/content/Mangio-RVC-Fork/logs/Nethaji1', 'v2']
# /content/Mangio-RVC-Fork/logs/Nethaji1
# load model(s) from hubert_base.pt
# /usr/local/lib/python3.10/dist-packages/fairseq/checkpoint_utils.py:315: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state = torch.load(f, map_location=torch.device("cpu"))
# 2024-11-17 15:27:42 | INFO | fairseq.tasks.hubert_pretraining | current directory is /content/Mangio-RVC-Fork
# 2024-11-17 15:27:42 | INFO | fairseq.tasks.hubert_pretraining | HubertPretrainingTask Config {'_name': 'hubert_pretraining', 'data': 'metadata', 'fine_tuning': False, 'labels': ['km'], 'label_dir': 'label', 'label_rate': 50.0, 'sample_rate': 16000, 'normalize': False, 'enable_padding': False, 'max_keep_size': None, 'max_sample_size': 250000, 'min_sample_size': 32000, 'single_target': False, 'random_crop': True, 'pad_audio': False}
# 2024-11-17 15:27:42 | INFO | fairseq.models.hubert.hubert | HubertModel Config: {'_name': 'hubert', 'label_rate': 50.0, 'extractor_mode': default, 'encoder_layers': 12, 'encoder_embed_dim': 768, 'encoder_ffn_embed_dim': 3072, 'encoder_attention_heads': 12, 'activation_fn': gelu, 'layer_type': transformer, 'dropout': 0.1, 'attention_dropout': 0.1, 'activation_dropout': 0.0, 'encoder_layerdrop': 0.05, 'dropout_input': 0.1, 'dropout_features': 0.1, 'final_dim': 256, 'untie_final_proj': True, 'layer_norm_first': False, 'conv_feature_layers': '[(512,10,5)] + [(512,3,2)] * 4 + [(512,2,2)] * 2', 'conv_bias': False, 'logit_temp': 0.1, 'target_glu': False, 'feature_grad_mult': 0.1, 'mask_length': 10, 'mask_prob': 0.8, 'mask_selection': static, 'mask_other': 0.0, 'no_mask_overlap': False, 'mask_min_space': 1, 'mask_channel_length': 10, 'mask_channel_prob': 0.0, 'mask_channel_selection': static, 'mask_channel_other': 0.0, 'no_mask_channel_overlap': False, 'mask_channel_min_space': 1, 'conv_pos': 128, 'conv_pos_groups': 16, 'latent_temp': [2.0, 0.5, 0.999995], 'skip_masked': False, 'skip_nomask': False, 'checkpoint_activations': False, 'required_seq_len_multiple': 2, 'depthwise_conv_kernel_size': 31, 'attn_type': '', 'pos_enc_type': 'abs', 'fp16': False}
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:143: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# move model to cuda
# all-feature-389
# all-feature-done

# %%
#@title Save preprocessed dataset files to Google Drive
#Compress dataset folder
loc = "%s/logs/%s" % (now_dir, experiment_name)
# !zip -r rvcLogs.zip "{loc}"
DATASET_PATH_DRIVE = "/content/drive/MyDrive/rvcDisconnected/" + experiment_name
# !mkdir -p "{DATASET_PATH_DRIVE}"
# !cp /content/Mangio-RVC-Fork/rvcLogs.zip "{DATASET_PATH_DRIVE}"
# Out:
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/ (stored 0%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/ (stored 0%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_25.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_3.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_20.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_17.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_0.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_10.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_22.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_11.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_3.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_9.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_17.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_14.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_10.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_7.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_4.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_5.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_5.wav (deflated 7%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_22.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_17.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_5.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_17.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_24.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_19.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_7.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_16.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_19.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_19.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_8.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_7.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_20.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_2.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_1.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_12.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_25.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_20.wav (deflated 7%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_19.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_10.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_24.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_10.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_23.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_13.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_1.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_14.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_1.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_25.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_20.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_9.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_11.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_24.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_7.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_15.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_9.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_7.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_11.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_8.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_7.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_25.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_9.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_26.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_7.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_19.wav (deflated 7%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_5.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_20.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_2.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_20.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_13.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_14.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_12.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_6.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_1.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_7.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_10.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_21.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_13.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_22.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_18.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_12.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_2.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_11.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_27.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_12.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_19.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_10.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_13.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_16.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_9.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_7.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_24.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_9.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_24.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_6.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_9.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_6.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_19.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_6.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_14.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_20.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_21.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_25.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_4.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_1.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_14.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_16.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_9.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_17.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_13.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_2.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_8.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_21.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_11.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_18.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_3.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_12.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_18.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_14.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_6.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_5.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_14.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_14.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_15.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_26.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_12.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_15.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_22.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_23.wav (deflated 7%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_24.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_16.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_18.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_7.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_19.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_7.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_1.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_13.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_9.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_10.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_11.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_15.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_10.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_12.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_19.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_13.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_10.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_22.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_24.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_15.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_13.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_2.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_5.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_17.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_11.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_2.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_18.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_4.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_16.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_25.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_7.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_13.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_0.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_20.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_17.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_9.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_6.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_20.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_20.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_15.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_4.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_21.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_14.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_11.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_9.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_22.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_4.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_4.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_21.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_12.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_18.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_14.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_5.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_15.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_12.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_17.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_19.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_11.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_17.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_3.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_13.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_26.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_23.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_16.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_11.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_12.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_13.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_16.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_17.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_23.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_23.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_6.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_20.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_6.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_17.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_1.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_18.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_23.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_15.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_18.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_9.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_15.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_8.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_25.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_16.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_18.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_22.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_2.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_2.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_20.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_15.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_6.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_23.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_20.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_8.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_6.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_16.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_12.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_0.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_5.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_5.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_12.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_1.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_6.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_14.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_13.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_11.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_12.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_23.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_25.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_14.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_1.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_14.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_21.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_16.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_14.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_3.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_10.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_22.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_9.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_10.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_0.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_20.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_24.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_21.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_22.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_8.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_24.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_1.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_19.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_4.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_8.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_7.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_8.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_17.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_4.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_8.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_23.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_7.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_19.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_8.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_15.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_19.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_4.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_25.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_1.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_21.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_19.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_5.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_2.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_18.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_22.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_2.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_10.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_6.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_27.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_11.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_16.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_8.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_7.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_23.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_15.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_13.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_19.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_15.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_8.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_21.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_5.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_7.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_21.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_21.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_20.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_15.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_23.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_11.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_23.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_24.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_17.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_17.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_21.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_4.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_10.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_13.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_14.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_22.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_14.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_3.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_18.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_16.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_4.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_2.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_4.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_10.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_6.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_10.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_2.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_22.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_17.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/20_7.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_18.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_1.wav (deflated 4%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_9.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_11.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_11.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_9.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_15.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/1_10.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_18.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/15_19.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/11_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_24.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_15.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_5.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_2.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_18.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/5_7.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/16_5.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/12_2.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_2.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/0_5.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_14.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_19.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_24.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_24.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_6.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/2_17.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/13_0.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/18_20.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/17_5.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/14_21.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/6_16.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_4.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/9_5.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/7_15.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_3.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/19_21.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/8_20.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/3_22.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/4_18.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_13.wav (deflated 5%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/1_16k_wavs/10_16.wav (deflated 6%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/ (stored 0%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/20_9.wav.npy (deflated 37%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_25.wav.npy (deflated 18%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/10_23.wav.npy (deflated 22%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/16_17.wav.npy (deflated 22%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/12_11.wav.npy (deflated 29%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/11_26.wav.npy (deflated 35%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/11_24.wav.npy (deflated 40%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/8_11.wav.npy (deflated 24%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/16_14.wav.npy (deflated 31%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/2_17.wav.npy (deflated 29%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/17_24.wav.npy (deflated 31%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/1_6.wav.npy (deflated 24%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/11_22.wav.npy (deflated 41%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_10.wav.npy (deflated 28%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/17_13.wav.npy (deflated 18%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/13_15.wav.npy (deflated 23%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/20_0.wav.npy (deflated 16%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/10_10.wav.npy (deflated 18%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_8.wav.npy (deflated 27%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/6_19.wav.npy (deflated 31%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_12.wav.npy (deflated 36%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/5_14.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/13_21.wav.npy (deflated 29%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/5_4.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/5_0.wav.npy (deflated 31%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/8_8.wav.npy (deflated 25%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/5_5.wav.npy (deflated 36%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/10_1.wav.npy (deflated 21%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/19_9.wav.npy (deflated 19%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/0_22.wav.npy (deflated 30%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/2_0.wav.npy (deflated 10%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/20_20.wav.npy (deflated 33%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/19_22.wav.npy (deflated 14%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_20.wav.npy (deflated 40%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/6_9.wav.npy (deflated 25%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/17_12.wav.npy (deflated 30%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/1_12.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/20_10.wav.npy (deflated 22%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/1_1.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/12_15.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/19_21.wav.npy (deflated 21%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_7.wav.npy (deflated 33%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/18_1.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/6_14.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/6_22.wav.npy (deflated 41%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/16_19.wav.npy (deflated 33%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/9_15.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/16_11.wav.npy (deflated 24%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/14_10.wav.npy (deflated 18%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/1_17.wav.npy (deflated 30%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/2_24.wav.npy (deflated 36%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/2_27.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/19_13.wav.npy (deflated 22%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_11.wav.npy (deflated 27%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/18_7.wav.npy (deflated 25%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_19.wav.npy (deflated 32%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/13_24.wav.npy (deflated 22%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_15.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/11_1.wav.npy (deflated 27%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/20_15.wav.npy (deflated 28%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_1.wav.npy (deflated 27%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/5_10.wav.npy (deflated 17%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/20_18.wav.npy (deflated 24%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/14_18.wav.npy (deflated 30%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_2.wav.npy (deflated 35%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_25.wav.npy (deflated 33%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/5_3.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/7_11.wav.npy (deflated 36%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/19_18.wav.npy (deflated 19%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/18_18.wav.npy (deflated 19%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/17_21.wav.npy (deflated 21%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/20_7.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/19_14.wav.npy (deflated 11%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/12_22.wav.npy (deflated 15%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/5_19.wav.npy (deflated 39%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/16_20.wav.npy (deflated 24%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/17_16.wav.npy (deflated 32%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/17_17.wav.npy (deflated 15%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/1_3.wav.npy (deflated 37%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/13_13.wav.npy (deflated 30%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/8_3.wav.npy (deflated 14%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/15_3.wav.npy (deflated 18%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/10_12.wav.npy (deflated 10%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/8_4.wav.npy (deflated 21%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/14_9.wav.npy (deflated 32%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/11_4.wav.npy (deflated 32%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_10.wav.npy (deflated 27%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/15_4.wav.npy (deflated 18%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/7_6.wav.npy (deflated 37%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/13_11.wav.npy (deflated 18%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_22.wav.npy (deflated 37%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/0_17.wav.npy (deflated 28%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/14_21.wav.npy (deflated 32%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/8_14.wav.npy (deflated 21%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/17_11.wav.npy (deflated 29%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/6_23.wav.npy (deflated 32%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/6_10.wav.npy (deflated 29%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_3.wav.npy (deflated 24%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/11_19.wav.npy (deflated 32%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/14_1.wav.npy (deflated 24%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/15_23.wav.npy (deflated 25%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/5_6.wav.npy (deflated 31%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_0.wav.npy (deflated 35%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/0_15.wav.npy (deflated 29%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/0_14.wav.npy (deflated 45%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/8_21.wav.npy (deflated 27%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/16_5.wav.npy (deflated 19%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/11_23.wav.npy (deflated 41%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/2_14.wav.npy (deflated 28%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/11_5.wav.npy (deflated 40%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/15_14.wav.npy (deflated 19%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/18_19.wav.npy (deflated 38%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_24.wav.npy (deflated 51%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/15_11.wav.npy (deflated 11%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/1_7.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/6_20.wav.npy (deflated 28%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/18_11.wav.npy (deflated 21%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/11_10.wav.npy (deflated 23%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/13_14.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/17_3.wav.npy (deflated 24%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/20_16.wav.npy (deflated 30%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/1_25.wav.npy (deflated 25%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_17.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/3_17.wav.npy (deflated 33%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/9_12.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/18_22.wav.npy (deflated 21%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/14_23.wav.npy (deflated 38%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/14_16.wav.npy (deflated 25%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/5_20.wav.npy (deflated 31%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/19_16.wav.npy (deflated 13%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_6.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/16_21.wav.npy (deflated 31%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/12_0.wav.npy (deflated 16%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/5_17.wav.npy (deflated 28%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/10_15.wav.npy (deflated 30%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_19.wav.npy (deflated 18%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/7_21.wav.npy (deflated 24%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/2_13.wav.npy (deflated 28%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/10_16.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/17_9.wav.npy (deflated 22%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/1_10.wav.npy (deflated 15%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_13.wav.npy (deflated 23%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/2_9.wav.npy (deflated 27%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/18_3.wav.npy (deflated 21%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/8_6.wav.npy (deflated 13%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/18_8.wav.npy (deflated 17%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/11_11.wav.npy (deflated 25%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/11_27.wav.npy (deflated 41%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/16_18.wav.npy (deflated 39%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/2_6.wav.npy (deflated 19%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_18.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/14_7.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/5_24.wav.npy (deflated 30%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/0_20.wav.npy (deflated 24%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/14_2.wav.npy (deflated 22%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/10_22.wav.npy (deflated 21%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/6_7.wav.npy (deflated 29%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/7_18.wav.npy (deflated 23%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/2_4.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/13_23.wav.npy (deflated 42%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/15_6.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/1_5.wav.npy (deflated 19%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/18_0.wav.npy (deflated 23%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/13_7.wav.npy (deflated 21%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_0.wav.npy (deflated 34%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/9_6.wav.npy (deflated 42%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/12_16.wav.npy (deflated 17%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/1_14.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/10_6.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/18_4.wav.npy (deflated 27%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/2_18.wav.npy (deflated 24%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/14_25.wav.npy (deflated 21%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/6_8.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/15_9.wav.npy (deflated 18%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/13_9.wav.npy (deflated 35%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/13_16.wav.npy (deflated 20%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/7_10.wav.npy (deflated 19%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/15_13.wav.npy (deflated 14%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/20_4.wav.npy (deflated 18%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/4_21.wav.npy (deflated 30%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/16_2.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/7_20.wav.npy (deflated 25%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/10_20.wav.npy (deflated 26%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/6_13.wav.npy (deflated 27%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/15_7.wav.npy (deflated 12%)
# updating: content/Mangio-RVC-Fork/logs/Nethaji1/2b-f0nsf/0_7.wav.npy (deflated 20%)
# ...
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/12_0.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/3_8.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_7.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_0.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/11_3.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/19_9.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/18_4.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/8_19.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/5_3.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/18_6.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/17_1.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/10_6.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/12_19.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/7_7.spec.pt (deflated 14%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/18_3.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/0_20.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/7_10.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/8_8.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/20_16.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/17_8.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/2_10.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/12_11.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/14_17.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/5_10.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/11_24.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/17_10.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/17_11.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/9_10.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/19_19.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/20_9.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/20_11.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/3_2.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/7_3.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/13_3.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/5_24.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/14_6.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/18_16.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/5_14.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_18.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/18_14.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/14_19.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/18_9.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/4_22.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/12_12.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/6_13.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/0_9.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/0_17.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/12_21.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/3_10.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/19_17.spec.pt (deflated 15%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_23.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/5_6.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/14_10.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/14_9.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_24.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_15.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/8_3.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/7_13.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/2_0.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/9_5.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/0_14.spec.pt (deflated 14%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/11_11.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/6_4.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/9_9.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_19.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/13_5.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/10_13.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/2_2.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/3_15.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/4_21.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/14_18.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/2_15.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_12.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/2_17.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/7_24.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/5_19.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_22.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/19_7.spec.pt (deflated 16%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/19_23.spec.pt (deflated 14%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/7_9.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/5_11.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/4_18.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/17_21.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/0_13.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/11_23.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/20_15.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_3.spec.pt (deflated 14%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/0_2.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/5_8.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/10_25.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_19.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/11_26.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_12.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_1.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/0_23.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/0_16.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_16.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/20_10.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_25.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/6_20.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/18_12.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/20_2.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/13_2.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/12_2.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/0_21.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/13_18.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/13_16.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/15_3.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/14_16.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/12_3.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/8_26.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/6_12.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/14_25.spec.pt (deflated 10%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/10_0.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/4_2.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_0.spec.pt (deflated 14%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/17_9.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_14.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_21.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/20_0.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/8_20.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/17_13.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/8_18.spec.pt (deflated 14%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/12_9.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/3_4.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/2_14.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/18_11.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_24.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/5_15.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/8_10.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/10_2.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/15_4.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/6_22.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/19_16.spec.pt (deflated 14%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/20_17.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_3.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/14_5.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/11_20.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/18_0.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/9_22.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_14.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/8_21.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/16_5.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/3_1.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/11_7.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/10_12.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/2_18.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_21.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/9_12.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/18_21.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/18_19.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/6_3.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/9_2.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/9_20.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/7_20.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/15_19.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/4_1.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/0_25.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/7_6.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/5_17.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/13_15.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/13_9.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/8_4.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/2_4.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/19_5.spec.pt (deflated 14%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/17_17.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/1_20.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/2_27.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/13_20.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/3_20.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/15_16.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/13_13.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/20_1.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/15_7.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/19_11.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/13_10.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/15_0.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/10_1.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/6_19.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/19_21.spec.pt (deflated 13%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/14_3.spec.pt (deflated 11%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/0_gt_wavs/2_13.spec.pt (deflated 12%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/events.out.tfevents.1731855933.37de22480f54.22172.0 (deflated 3%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/config.json (deflated 70%)
#   adding: content/Mangio-RVC-Fork/logs/Nethaji1/filelist.txt (deflated 95%)

# %% [markdown]
# # Training
# Also includes resuming code.

# %%
#@title Load preprocessed dataset files from Google Drive (for resuming)
#@markdown If you already have preprocessed dataset files on Google Drive, you can load them here instead of re-running the preprocessing steps.
import os

BACK_UP_DATASET_PATH = "/content/drive/MyDrive/rvcDisconnected/" + experiment_name

#Prevent people from loading the ZIP over existing files
ok=True
if(os.path.exists("/content/Mangio-RVC-Fork/logs/"+experiment_name+"/2a_f0")):
  print("Dataset files already loaded, skipping.")
  ok=False

if ok:
  # !unzip "{BACK_UP_DATASET_PATH}/rvcLogs.zip" -d /

# %%
#@title Import Model from Drive to Notebook (for resuming)
import os

DATASET_PATH_DRIVE = "/content/drive/MyDrive/rvcDisconnected/" + experiment_name
DATASET_PATH_COLAB = "/content/Mangio-RVC-Fork/logs/" + experiment_name
#@markdown Input the model's Step Count here (the number located on your model's G and D files.) If you used `save_only_last_ckpt` during training, this number will be 2333333.
STEPCOUNT = 000 #@param {type:"integer"}

print("Copying model files...")
# !cp "{DATASET_PATH_DRIVE}/D_{STEPCOUNT}.pth" "{DATASET_PATH_COLAB}"
# !cp "{DATASET_PATH_DRIVE}/G_{STEPCOUNT}.pth" "{DATASET_PATH_COLAB}"
# !cp "{DATASET_PATH_DRIVE}/config.json" "{DATASET_PATH_COLAB}"

print("Copying Tensorboard TFEVENT files...")
for r, _, f in os.walk(DATASET_PATH_DRIVE):
  for name in f:
    if(name.startswith("events.out.tfevents")):
      # !cp "{DATASET_PATH_DRIVE}/{name}" "{DATASET_PATH_COLAB}"

print("All done. Welcome back!")

# %%
#@title Index Training
#@markdown Ensure that Feature Extraction has run successfully before running this cell.

#@markdown Use this option if you wish to save the two extra files generated by index training to your Google Drive. (Only the added index is normally needed.)
save_extra_files_to_drive = False #@param {type:"boolean"}

#@markdown **Advanced:** Select this option if you would like to force the trainer to use Minibatch K-Means instead of Faiss. *Do not enable this unless you know what you're doing.*
force_mbkm = False #@param {type:"boolean"}

#Oh dear lord why is this baked into infer-web I hate this
import os
import sys
import traceback
import numpy as np
import faiss

#from sklearn.cluster import MiniBatchKMeans

exp_dir = "%s/logs/%s" % (now_dir, experiment_name)
os.makedirs(exp_dir, exist_ok=True)
feature_dir = (
    "%s/3_feature256" % (exp_dir)
    if model_architecture == "v1"
    else "%s/3_feature768" % (exp_dir)
)
print(feature_dir)
if not os.path.exists(feature_dir):
  raise Exception("No features exist for this model yet. Did you run Feature Extraction?")
listdir_res = list(os.listdir(feature_dir))
if len(listdir_res) == 0:
  raise Exception("No features exist for this model yet. Did you run Feature Extraction?")

try:
  from sklearn.cluster import MiniBatchKMeans
except:
  print("Due to a bug with Colab, we will need to reinstall Numpy real quick. Give me a sec!")
  # !pip install -U numpy
  print("Numpy reinstalled. Please restart the runtime, and then re-run the \"Set Training Variables\" cell to continue.")
  sys.exit()
else:
  print("Proper Numpy version detected.")

infos=[]
npys=[]
for name in sorted(listdir_res):
  phone = np.load("%s/%s" % (feature_dir, name))
  npys.append(phone)
big_npy = np.concatenate(npys, 0)
big_npy_idx = np.arange(big_npy.shape[0])
np.random.shuffle(big_npy_idx)
if big_npy.shape[0] > 2e5 or force_mbkm:
  print("Trying doing kmeans %s shape to 10k centers." % big_npy.shape[0])
  try:
    big_npy = (
        MiniBatchKMeans(
            n_clusters=10000,
            verbose=True,
            batch_size=256,
            compute_labels = False,
            init="random"
        )
        .fit(big_npy)
        .cluster_centers_

    )
  except:
    info = traceback.format_exc()
    print(info)

np.save("%s/total_fea.npy" % exp_dir, big_npy)
n_ivf = min(int(16*np.sqrt(big_npy.shape[0])), big_npy.shape[0] // 39)
print("%s,%s" % (big_npy.shape, n_ivf))
index = faiss.index_factory(256 if model_architecture == "v1" else 768, "IVF%s,Flat" % n_ivf)
print("Training index...")
index_ivf = faiss.extract_index_ivf(index)
index_ivf.nprobe = 1
index.train(big_npy)
faiss.write_index(
    index,
    "%s/trained_IVF%s_Flat_nprobe_%s_%s_%s.index" % (exp_dir, n_ivf, index_ivf.nprobe, experiment_name, model_architecture)
)
print("Adding...")
batch_size_add = 8192
for i in range(0, big_npy.shape[0], batch_size_add):
  index.add(big_npy[i:i+batch_size_add])
faiss.write_index(
    index,
    "%s/added_IVF%s_Flat_nprobe_%s_%s_%s.index"
    % (exp_dir, n_ivf, index_ivf.nprobe, experiment_name, model_architecture)
)

npr = index_ivf.nprobe

print("Saving files to Drive...")
DATASET_PATH_DRIVE = "/content/drive/MyDrive/rvcDisconnected/" + experiment_name
if(not os.path.exists(DATASET_PATH_DRIVE)):
  # !mkdir -p "{DATASET_PATH_DRIVE}"
DATASET_PATH_COLAB = "/content/Mangio-RVC-Fork/logs/" + experiment_name
if(save_extra_files_to_drive):
  # !cp "{DATASET_PATH_COLAB}/total_fea.npy" "{DATASET_PATH_DRIVE}"
  # !cp "{DATASET_PATH_COLAB}/trained_IVF{n_ivf}_Flat_nprobe_{npr}_{experiment_name}_{model_architecture}.index" "{DATASET_PATH_DRIVE}"
# !cp "{DATASET_PATH_COLAB}/added_IVF{n_ivf}_Flat_nprobe_{npr}_{experiment_name}_{model_architecture}.index" "{DATASET_PATH_DRIVE}"

print("All done! Your index file has completed training.")
try:
  firsttry
except:
  print("If you had to restart the runtime, disconnect and delete the runtime in order to continue. (Restarting the runtime again will not work.)")
# Out:
# /content/Mangio-RVC-Fork/logs/Nethaji1/3_feature768
# Proper Numpy version detected.
# (54655, 768),1401
# Training index...
# Adding...
# Saving files to Drive...
# All done! Your index file has completed training.

# %%
import os
import math
from random import shuffle


assert 'model_architecture' in locals(), "Hold up! You need to run the  \"Set Training Variables\" cell first."


assert 'pretrain_type' in locals(), "You need to download a pretrain! Please run the \"Download Pretrained Model\" cell before continuing."


#@title Training
save_frequency = 50 #@param {type:"integer"}
total_epochs = 1024 #@param {type:"integer"}
batch_size = 8 #@param {type:"integer"}
save_only_latest_ckpt = True #@param {type:"boolean"}
cache_all_training_sets = False #@param {type:"boolean"}
save_small_final_model = True #@param {type:"boolean"}
#@markdown **Advanced:** You can manually define a log interval here.
use_manual_stepToEpoch = False #@param {type:"boolean"}
manual_stepToEpoch = 000 #@param {type:"integer"}

assert save_frequency!=None, "You need to input something for save_frequency, silly."
assert save_frequency>0, "Save frequency must be more than 0."
if(save_frequency>50):print(f"...A save frequency of {save_frequency}? A bit high, but... alright then.")
assert total_epochs!=None, "You need to input something for total_epochs, silly."
assert total_epochs>0, "Total epochs must be more than 0."
if(total_epochs>10000):print(f"...A total epoch count of of {total_epochs}? This is going to overtrain, but... alright then.")
assert batch_size!=None, "You need to input something for batch_size, silly."
assert batch_size>0, "Batch size must be more than 0."
assert batch_size<=40, "Batch size must be less than 40. (I'd reccomend a value between 6 and 12 for Colab.)"

pretrained_base = "pretrained/" if model_architecture == "v1" else "pretrained_v2/"
unpt = f"_{pretrain_type}" if pretrain_type!="original" else ""

pretrainedD = f"{pretrained_base}f0D{target_sample_rate}{unpt}.pth"
pretrainedG = f"{pretrained_base}f0G{target_sample_rate}{unpt}.pth"

#Log interval
log_interval = 1
liFolderPath = os.path.join(exp_dir, "1_16k_wavs")
if(os.path.exists(liFolderPath) and os.path.isdir(liFolderPath)):
  wav_files = [f for f in os.listdir(liFolderPath) if f.endswith(".wav")]
  if wav_files:
    sample_size = len(wav_files)
    log_interval = math.ceil(sample_size / batch_size)
    if log_interval > 1:
      log_interval += 1

if log_interval > 250 and not use_manual_stepToEpoch:
  print(f"That's a big dataset you got there. Log interval normalized to 200 steps from {log_interval} steps.")
  log_interval = 200

if use_manual_stepToEpoch:
  log_interval = manual_stepToEpoch

#Create Python command
cmd = "python train_nsf_sim_cache_sid_load_pretrain.py -e \"%s\" -sr %s -f0 %s -bs %s -g %s -te %s -se %s %s %s -l %s -c %s -sw %s -v %s -li %s" % (
    experiment_name,
    target_sample_rate,
    1,
    batch_size,
    0,
    total_epochs,
    save_frequency,
    "-pg %s" % pretrainedG if pretrainedG != "" else "\b",
    "-pd %s" % pretrainedD if pretrainedD != "" else "\b",
    1 if save_only_latest_ckpt else 0,
    1 if cache_all_training_sets else 0,
    1 if save_small_final_model else 0,
    model_architecture,
    log_interval,
)
print(cmd)

#Create mute filelist
gt_wavs_dir = f"{exp_dir}/0_gt_wavs"
feature_dir = (
  f"{exp_dir}/3_feature256"
  if model_architecture == "v1"
  else f"{exp_dir}/3_feature768"
)
f0_dir = f"{exp_dir}/2a_f0"
f0nsf_dir = f"{exp_dir}/2b-f0nsf"
names = (
  set([name.split(".")[0] for name in os.listdir(gt_wavs_dir)])
  & set([name.split(".")[0] for name in os.listdir(feature_dir)])
  & set([name.split(".")[0] for name in os.listdir(f0_dir)])
  & set([name.split(".")[0] for name in os.listdir(f0nsf_dir)])
)
opt = []
for name in names:
  opt.append(
    "%s/%s.wav|%s/%s.npy|%s/%s.wav.npy|%s/%s.wav.npy|%s"
    % (
      gt_wavs_dir.replace("\\", "\\\\"),
      name,
      feature_dir.replace("\\", "\\\\"),
      name,
      f0_dir.replace("\\", "\\\\"),
      name,
      f0nsf_dir.replace("\\", "\\\\"),
      name,
      speaker_id,
    )
  )
fea_dim = 256 if model_architecture == "v1" else 768
for _ in range(2):
  opt.append(
      f"{now_dir}/logs/mute/0_gt_wavs/mute{target_sample_rate}.wav|{now_dir}/logs/mute/3_feature{fea_dim}/mute.npy|{now_dir}/logs/mute/2a_f0/mute.wav.npy|{now_dir}/logs/mute/2b-f0nsf/mute.wav.npy|{speaker_id}"
  )
shuffle(opt)
with open(f"{exp_dir}/filelist.txt", "w") as f:
  f.write("\n".join(opt))
print("Mute filelist written. Best of luck training!")


# %cd /content/Mangio-RVC-Fork
# %load_ext tensorboard
# %tensorboard --logdir /content/Mangio-RVC-Fork/logs

os.chdir('/content/Mangio-RVC-Fork')
# !$cmd
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-1-008db2cce89b> in <cell line: 6>()
#       4
#       5
# ----> 6 assert 'model_architecture' in locals(), "Hold up! You need to run the  \"Set Training Variables\" cell first."
#       7
#       8
#
# AssertionError: Hold up! You need to run the  "Set Training Variables" cell first.

# %%
#@title Export Model from Notebook to Drive
import os

DATASET_PATH_DRIVE = "/content/drive/MyDrive/rvcDisconnected/" + experiment_name
DATASET_PATH_COLAB = "/content/Mangio-RVC-Fork/logs/" + experiment_name
if(not os.path.exists(DATASET_PATH_DRIVE)):
  # !mkdir -p "{DATASET_PATH_DRIVE}"

#@markdown **Advanced:** Use this option if you wish to only copy over weights.
skip_models = False #@param {type:"boolean"}
#@markdown **Advanced:** Use these options if you wish to manually input your step count and epoch count for incomplete models. *Do not use this option if your training finished.*
manual_save = False #@param {type:"boolean"}
STEPCOUNT = 000 #@param {type:"integer"}
EPOCHCOUNT = 000 #@param {type:"integer"}

finished=False
potential="/content/Mangio-RVC-Fork/weights/"+experiment_name+".pth"
if os.path.exists(potential):
  finished = True

#VERY hacky. Might break stuff, report to me if it does.
print("Detecting latest model...")
if(not manual_save):
  currentMax = 0
  for r, _, f in os.walk("/content/Mangio-RVC-Fork/weights/"):
    for name in f:
      if(name.endswith(".pth") and (name!=experiment_name+".pth")):
        #Check to see if this PTH is what we're looking for.
        if(name.find(experiment_name)==-1):
          continue
        #Determine Epochcount+Stepcount Phase 1
        pot = name.split('_')
        ep=pot[len(pot)-2][1:]
        #If what we got from the epoch count section of the filename isn't a number, multiple completed models are in weights.
        #Skip it if that happens.
        if(not ep.isdecimal()):
          continue
        #Determine Epochcount+Stepcount Phase 2
        ep=int(ep)
        if ep>currentMax:
          currentMax=ep
          step=pot[len(pot)-1].split('.')
          step=int(step[0][1:])
          EPOCHCOUNT=ep
          STEPCOUNT=step

TSTEP = STEPCOUNT
if(not skip_models):
  print("Copying model files...")
  if(save_only_latest_ckpt):
    TSTEP=2333333
  # !cp "{DATASET_PATH_COLAB}/D_{TSTEP}.pth" "{DATASET_PATH_DRIVE}"
  # !cp "{DATASET_PATH_COLAB}/G_{TSTEP}.pth" "{DATASET_PATH_DRIVE}"
  # !cp "{DATASET_PATH_COLAB}/config.json" "{DATASET_PATH_DRIVE}"

print("Copying Tensorboard TFEVENT files...")
for r, d, f in os.walk(DATASET_PATH_COLAB):
  for name in f:
    if(name.startswith("events.out.tfevents") and os.path.exists(os.path.join(DATASET_PATH_COLAB, name))):
      # !cp "{DATASET_PATH_COLAB}/{name}" "{DATASET_PATH_DRIVE}"

print("Copying weight file...")
if(finished):
  # !cp "{potential}" "{DATASET_PATH_DRIVE}"
else:
  # !cp "/content/Mangio-RVC-Fork/weights/{experiment_name}_e{EPOCHCOUNT}_s{STEPCOUNT}.pth" "{DATASET_PATH_DRIVE}"

print("All done!")

# %%
#@title Export Finished Model to HuggingFace
#Credit to LollenApe for this cell!

#TODO:
#maybe remove glob dependency?

import os
import zipfile
import glob

assert experiment_name, "No experiment name found."

#@markdown **Advanced:** Use this option if you wish to manually use a specific epoch value. *Leave this blank if your model finished training.*
manual_epoch_number = "" #@param {type:"string"}
num_epochs = int(manual_epoch_number) if manual_epoch_number.isdigit() else None

# Construct the weights path based on the provided number of epochs
if num_epochs is not None:
  weights_path = f"/content/Mangio-RVC-Fork/weights/{experiment_name}_e{num_epochs}*"
else:
  print("Autodetecting epoch count...")
  potential = f"/content/Mangio-RVC-Fork/weights/{experiment_name}.pth"
  if os.path.exists(potential):
    weights_path = f"/content/Mangio-RVC-Fork/weights/{experiment_name}"
  else:
    currentMax = 0
    for r, _, f in os.walk("/content/Mangio-RVC-Fork/weights/"):
      for name in f:
        if(name.endswith(".pth") and (name!=experiment_name+".pth")):
          if(name.find(experiment_name)==-1):
            continue
          pot = name.split('_')
          ep=pot[len(pot)-2][1:]
          if(not ep.isdecimal()):
            continue
          ep=int(ep)
          if ep>currentMax:
            currentMax=ep
    num_epochs=currentMax
    weights_path = f"/content/Mangio-RVC-Fork/weights/{experiment_name}_e{num_epochs}*"
  print(f"Model with path {weights_path} found automatically.")

weights_files = glob.glob(weights_path + ".pth")
logs_path = f"/content/Mangio-RVC-Fork/logs/{experiment_name}/added_*_1_{experiment_name}_{model_architecture}.index"

print(f"Searching for weights files in: {weights_path}.pth")
print(f"Searching for logs file in: {logs_path}")

if weights_files and any(glob_result := glob.glob(logs_path)):
    log_file = glob_result[0]
    output_folder = "/content/toHF"
    os.makedirs(output_folder, exist_ok=True)
    output_zip_path = f"{output_folder}/{experiment_name}.zip"
    with zipfile.ZipFile(output_zip_path, 'w') as zipf:
        for weights_file in weights_files:
            zipf.write(weights_file, os.path.basename(weights_file))
        zipf.write(log_file, os.path.basename(log_file))
    print(f"The files have been added to the zip folder: {output_zip_path}")
else:
    print(f"Found weights files: {weights_files}")
    print(f"Found logs files: {glob_result}")
    raise Exception("Couldn't find your model files. Check the found file results above. (Did you run Index Training?)")

from huggingface_hub import login, HfApi
#@markdown Enter HuggingFace Token (set Role to 'write'):
hftoken = "Obtain this at https://huggingface.co/settings/tokens" #@param {type:"string"}

# Login
login(token=f"{hftoken}")

#@markdown Set this option to true if you wish to create a new repository for this model.
create_new_repo = False #@param {type:"boolean"}
#@markdown Enter the HuggingFace repository name you wish to send the model to:
repoid = "username/RepoName" #@param {type:"string"}

if create_new_repo:
    from huggingface_hub import create_repo
    create_repo(repoid)
    print(f"Repo '{repoid}' created successfully!")

api = HfApi()
# Upload folders
api.upload_folder(folder_path="/content/toHF",
                 repo_id=f"{repoid}",
                 repo_type="model")

# %% [markdown]
# # Changelogs, Credits, and Special Thanks
#
# **Changelogs**
#
# **v0.28** - Added Blaise-TK's TITAN pretrains.
#
# Older changelogs can be found at https://rentry.co/rvcdisconnected_changelogs.
#
# **Credits**
# *   [Kit Lemonfoot](https://huggingface.co/Kit-Lemonfoot) - writing this notebook
# *   [RVC Project](https://github.com/RVC-Project) - Created RVC, obviously
# *   [Mangio261](https://github.com/Mangio621/) - Creating the Mangio RVC fork
# *   [Kalomaze](https://github.com/kalomaze) - Original RVC colab + Mangio tweaks
# *   [Alexlnkp](https://github.com/alexlnkp) - Created a more up-to-date variant of the Mangio-RVC fork
# *   [LollenApe](https://huggingface.co/lollenape) - Created the "Export Finished Model to HuggingFace" cell
# *   [Sonphantrung](https://github.com/sonphantrung) - Large amounts of code auditing and adjustments
# *   [LJ1995](https://huggingface.co/lj1995) - Pretrained RVC models
# *   [SimplCup](https://huggingface.co/SimplCup) - OV2Super pretrained RVC models
# *   [MUSTAR](https://huggingface.co/MUSTAR) - RIN_E3 and SnowieRU pretrained RVC models
# *   [TheStinger / Ilaria](https://huggingface.co/TheStinger) - ItaIla pretrained RVC models
# *   [Blaise-TK](https://huggingface.co/blaise-tk) - TITAN pretrained RVC models
# *   [Pony Preservation Project](https://boards.4channel.org/mlp/catalog#s=Pony%20Preservation%20Project) - for their robust TalkNet and So-Vits-SVC notebooks
# *   the Colab team - forcing my hand and making me release this notebook early
#
# **Special Thanks**
# *   [Fifteen AI](https://15.ai/) - for getting me into voice AI in the first place
# *   [Dacoolkid44](https://huggingface.co/dacoolkid44) / [HoloAI44](https://www.youtube.com/@Holo_AI44) and Hijack / [SANSSWEEP](https://huggingface.co/SANSSWEEP) - for basically kickstarting the larger VTuber voice AI scene with their models
# *   [Maki Ligon](https://www.youtube.com/@Shiina_Mashiro) / [Yuuto Ichika](https://www.youtube.com/@yuutoichika) - for keeping me grounded in reality while developing this thing
# *   [Bartezes](https://www.youtube.com/@bartezes3082) - for helping me so much with the [VTuber AI Model Tracking spreadsheet](https://docs.google.com/spreadsheets/d/1tvZSggOsZGAPjbMrWOAAaoJJFpJuQlwUEQCf5x1ssO8/)
# *   [Megaaziib](https://www.youtube.com/@megaaziib) - for inspiring me to keep working on AI models and covers (I don't hate you)
# *   [Saintlysaint](https://www.youtube.com/@SaintlySaint) and [Gengar2525](https://www.youtube.com/@GeGaCh) - for having faith in me
